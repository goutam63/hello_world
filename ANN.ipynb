# %% [markdown]
# <a href="https://colab.research.google.com/github/goutam63/hello_world/blob/main/ANN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# (Biological neuron)
# cerebral cortex of brain
# ## ANN

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### read data

# %%
data=pd.read_csv('diabetes.csv')

# %%
data
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ## checking the data for null

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.heatmap(data)

# %%
x=data.iloc[:,:-1]

# %%
y=data.iloc[:,-1]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  ...   BMI  DiabetesPedigreeFunction  Age
# 0              6      148             72  ...  33.6                     0.627   50
# 1              1       85             66  ...  26.6                     0.351   31
# 2              8      183             64  ...  23.3                     0.672   32
# 3              1       89             66  ...  28.1                     0.167   21
# 4              0      137             40  ...  43.1                     2.288   33
# ..           ...      ...            ...  ...   ...                       ...  ...
# 763           10      101             76  ...  32.9                     0.171   63
# 764            2      122             70  ...  36.8                     0.340   27
# 765            5      121             72  ...  26.2                     0.245   30
# 766            1      126             60  ...  30.1                     0.349   47
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %% [markdown]
# keras frame work

# %%
from keras import Sequential # seuential model our Ann is basically Sequential model

# %%
from keras.layers import Dense

# %%
import keras

# %%
model=Sequential() # initialize model

# %% [markdown]
# ## adding layers

# %%
# adding layers
model.add(Dense(units = 8, input_dim = 8)) # 
model.add(Dense(units = 12, activation = 'relu'))
model.add(Dense(units = 1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics=['accuracy'])

# %% [markdown]
# ## train the model

# %%
history=model.fit(x,y,epochs=500,validation_data=(x_test,y_test), batch_size=10,verbose=1)
# Out:
# Epoch 1/500
# 77/77 [==============================] - 0s 3ms/step - loss: 0.5994 - accuracy: 0.6992 - val_loss: 0.6129 - val_accuracy: 0.7047
# Epoch 2/500
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6072 - accuracy: 0.6888 - val_loss: 0.5835 - val_accuracy: 0.7323
# Epoch 3/500
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6011 - accuracy: 0.6953 - val_loss: 0.5794 - val_accuracy: 0.7205
# Epoch 4/500
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6012 - accuracy: 0.6940 - val_loss: 0.6136 - val_accuracy: 0.7165
# Epoch 5/500
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6047 - accuracy: 0.6888 - val_loss: 0.6140 - val_accuracy: 0.7047
# Epoch 6/500
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6082 - accuracy: 0.6901 - val_loss: 0.5896 - val_accuracy: 0.7165
# Epoch 7/500
# ...

# %% [markdown]
# epochs= it is itaration,
# batch_size= it is number size of batch is model,
# sgd=secastic grediant degredation,

# %%
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model acuuracy')
plt.xlabel('ephoch')
plt.ylabel('accuracy')
plt.legend(['train','test'],loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
weights=model.get_weights()

# %%
weights
# Out:
# [array([[-0.41935393,  1.2406608 ,  0.10650884, -0.4240497 , -0.2701649 ,
#           1.0944525 ,  0.79684573,  0.3216606 ],
#         [-0.44326857,  0.20070349,  0.13123582, -0.2534867 , -0.09530404,
#           0.13499239, -0.18163301,  0.2692468 ],
#         [ 0.2494139 , -0.7505427 , -0.15148863,  0.10059291,  0.64320433,
#          -0.4130351 ,  0.28289187, -0.03396775],
#         [ 0.3270291 , -0.16614845, -0.4021169 , -0.3797587 , -0.548694  ,
#           0.041384  ,  0.04608236, -0.22905946],
#         [ 0.01196484, -0.03510089,  0.03553231, -0.01636987,  0.05712606,
#          -0.0022675 ,  0.0507573 ,  0.01754454],
#         [-0.04409365,  0.58094186, -0.49093577, -0.5114728 , -0.18319048,
#          -0.4713058 , -0.87127066, -0.05599888],
#         [ 0.5314128 ,  0.45116267, -0.5376892 , -0.63225687,  0.21790592,
#          -0.12514105,  0.45199364, -0.17325507],
#         [ 0.7822965 ,  0.34196383,  0.8334566 ,  0.20543167, -0.34211072,
# ...

# %%
weights, biases=model.layers[0].get_weights()

# %%
biases
# Out:
# array([ 0.15748794, -0.1993506 ,  0.05056894,  0.16663538,  0.09112807,
#        -0.03394889,  0.03913487, -0.06124196], dtype=float32)

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train','test'],loc='upper left')
plt.show()
